# %% [markdown]
# # Unit 1 Individual Project
#
# Brandon Keenan
#
# CS379 Machine Learning
#
# June 19, 2024

# %%
# Description

# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
titanic = pd.read_csv('titanic.csv')

# Print the first 10 rows of data
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
# Count the number of rows and columns in the data set
titanic.shape
# Out:
# (1310, 14)

# %%
# Stats about the data
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# Get a count of the number of surivors 
titanic['survived'].value_counts()
# Out:
# 0.0    809
# 1.0    500
# Name: survived, dtype: int64

# %%
# Visualize the count of number of survivors
sns.countplot(x='survived', data=titanic)
# Out:
# <AxesSubplot: xlabel='survived', ylabel='count'>

# %%
# add category column to dataframe so we show data on men, women, and children survival rates

def categorize_person(row):
    if row['age'] < 18:
        return 'child'
    elif row['sex'] == 'female':
        return 'woman'
    elif row['sex'] == 'male':
        return 'man'

    
titanic['category'] = df.apply(categorize_person, axis=1)

titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest category
# ...

# %%
# Visualize the count of survivors for columns 'category', 'sex', 'pclass', 'sibsp', 'parch', 'embarked'
cols = ['category', 'sex', 'pclass', 'sibsp', 'parch', 'embarked']

n_rows = 3
n_cols = 2


# The subplot grid and the figure size of each graph
# This returns a Figure (fig) and Axes Object (axs)
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*3.2, n_rows*3.2))

for r in range(0, n_rows):
    for c in range(0, n_cols):
        
        i = r*n_cols+ c #index to go through the number of columns
        ax = axs[r][c] #Show where to position each subplot
        sns.countplot(x = cols[i], hue ='survived', data=titanic, ax= ax)
        ax.set_title(cols[i])
        ax.legend(title="survived", loc='upper right')
        
plt.tight_layout()
